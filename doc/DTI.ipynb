# %%
from tdc.multi_pred import DTI
from rdkit import Chem
from rdkit.Chem import Draw

# %%
data = DTI(name = 'BindingDB_Kd')
data = DTI(name = 'BindingDB_IC50')
data = DTI(name = 'BindingDB_Ki')
# split = data.get_split()
# Out:
# Found local copy...
# Loading...
# Done!
# Found local copy...
# Loading...
# Done!
# Downloading...
# 100%|██████████| 236M/236M [00:37<00:00, 6.22MiB/s]
# Loading...
# Done!

# %%
mol = Chem.MolFromSmiles('Cc1[nH]nc2ccc(-c3cncc(OCC(N)Cc4ccccc4)c3)cc12')
Draw.MolToImage(mol)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
mol = Chem.MolFromSmiles('Clc1ccc(Nc2nnc(Cc3ccncc3)c3ccccc23)cc1')
Draw.MolToImage(mol)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
