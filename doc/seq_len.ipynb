# %%
from tdc.multi_pred import DTI
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
name = "DAVIS"
data_dti = DTI(name = name,path = "../data")
df = data_dti.get_data()
df['dlen'] = df['Drug'].str.len()
df['tlen'] = df['Target'].str.len()
df.to_csv(f"../data/{name}_seq_len.csv")
drug = df['dlen'].value_counts()
target = df['tlen'].value_counts()

f,axes = plt.subplots(1,2,figsize=(14,5))

sub_graph = axes[0]
sub_graph.scatter(drug.index,drug.values,alpha=0.5)
sub_graph.set_title(f"drug sequence on {name} dataset")
sub_graph.set_xlabel("length")
sub_graph.set_ylabel("count")

sub_graph = axes[1]
sub_graph.scatter(target.index,target.values,alpha=0.5)
sub_graph.set_title(f"target sequence on {name} dataset")
sub_graph.set_xlabel("length")
sub_graph.set_ylabel("count")
# Out:
# Found local copy...
# Loading...
# Done!
# Text(0, 0.5, 'count')

# %%
name = "BindingDB_Kd"
data_dti = DTI(name = name,path = "../data")
df = data_dti.get_data()
df['dlen'] = df['Drug'].str.len()
df['tlen'] = df['Target'].str.len()
df.to_csv(f"../data/{name}_seq_len.csv")
drug = df['dlen'].value_counts()
target = df['tlen'].value_counts()

f,axes = plt.subplots(1,2,figsize=(14,5))

sub_graph = axes[0]
sub_graph.scatter(drug.index,drug.values,alpha=0.5)
sub_graph.set_title(f"drug sequence on {name} dataset")
sub_graph.set_xlabel("length")
sub_graph.set_ylabel("count")

sub_graph = axes[1]
sub_graph.scatter(target.index,target.values,alpha=0.5)
sub_graph.set_title(f"target sequence on {name} dataset")
sub_graph.set_xlabel("length")
sub_graph.set_ylabel("count")
# Out:
# Found local copy...
# Loading...
# Done!
# Text(0, 0.5, 'count')

# %%
name = "KIBA"
data_dti = DTI(name = name,path = "../data")
df = data_dti.get_data()
df['dlen'] = df['Drug'].str.len()
df['tlen'] = df['Target'].str.len()
df.to_csv(f"../data/{name}_seq_len.csv")
drug = df['dlen'].value_counts()
target = df['tlen'].value_counts()

f,axes = plt.subplots(1,2,figsize=(14,5))

sub_graph = axes[0]
sub_graph.scatter(drug.index,drug.values,alpha=0.5)
sub_graph.set_title(f"drug sequence on {name} dataset")
sub_graph.set_xlabel("length")
sub_graph.set_ylabel("count")

sub_graph = axes[1]
sub_graph.scatter(target.index,target.values,alpha=0.5)
sub_graph.set_title(f"target sequence on {name} dataset")
sub_graph.set_xlabel("length")
sub_graph.set_ylabel("count")
# Out:
# Found local copy...
# Loading...
# Done!
# Text(0, 0.5, 'count')
